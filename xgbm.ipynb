# %%
import gc
import wandb
import pickle
import numpy as np 
import pandas as pd
from tqdm import tqdm 

import torch 
from torch import nn
from torch.utils.data import DataLoader 

from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split

from src.model.utils import load_embeddings
from src.model.data_utils import APNDataset, EMBDataset
from src.model.model import SModel
from src.model.train_utils import train_model
from src.utils import load_code_to_idx

from src.transactions_emb import create_transactions_embeddings
from src.clickstream_emb import create_clickstream_embeddings


from src.model.data_utils import EMBDataset
from src.model.utils import load_model
from typing import Dict

# %%
TRAIN_MATCHING_PATH = "/home/glebk/VSProjects/projects/Matching/data/train_matching.csv"
TRANSACTIONS_PATH = "/home/glebk/VSProjects/projects/Matching/data/transactions.csv"
CLICKSTREAM_PATH = "/home/glebk/VSProjects/projects/Matching/data/clickstream.csv"

# %%
def create_vtb_embeddings_for_model(
    transactions, model, mcc_code_to_idx, device
) -> Dict:

    bank_trans_emb = create_transactions_embeddings(transactions, mcc_code_to_idx)

    emb_dataset = EMBDataset(bank_trans_emb, "vtb")
    emb_dataset_loader = DataLoader(emb_dataset, 256, shuffle=False)

    embs = []
    emb_iter = iter(emb_dataset_loader)
    for i in range(len(emb_iter)):
        data = next(emb_iter)
        emb_batch = model(data.to(device), mode="anchor")
        embs.append(emb_batch)

    embs = torch.cat(embs, dim=0)
    embs = embs.detach().cpu().numpy()

    uids = bank_trans_emb["user_id"].values

    embs_dict = dict(zip(uids, embs))

    print("vtb embs shape: ", embs.shape)

    return embs_dict

# %%
def create_rtk_embeddings_for_model(
    clickstream, model, cat_code_to_idx, device
) -> Dict:

    rtk_emb = create_clickstream_embeddings(clickstream, cat_code_to_idx)

    emb_dataset = EMBDataset(rtk_emb, "rtk")
    emb_dataset_loader = DataLoader(emb_dataset, 256, shuffle=False)

    embs = []
    emb_iter = iter(emb_dataset_loader)
    for i in range(len(emb_iter)):
        data = next(emb_iter)
        emb_batch = model(data.to(device), mode="positive")
        embs.append(emb_batch)

    embs = torch.cat(embs, dim=0)
    embs = embs.detach().cpu().numpy()

    uids = rtk_emb["user_id"].values

    embs_dict = dict(zip(uids, embs))

    print("rtk embs shape: ", embs.shape)

    return embs_dict

# %%
# Load raw transactions:

transactions = pd.read_csv(TRANSACTIONS_PATH)
print(transactions.shape)
# Out:
# (19821910, 5)

# %%
# Load raw clickstream:

clickstream = pd.read_csv(CLICKSTREAM_PATH)
clickstream.head()
# Out:
#                             user_id  cat_id            timestamp  new_uid
# 0  000143baebad4467a23b98c918ccda19     165  2021-01-30 20:08:12  1873448
# 1  000143baebad4467a23b98c918ccda19     165  2021-01-31 20:06:29  1873448
# 2  000143baebad4467a23b98c918ccda19     308  2021-01-31 20:12:00  1873448
# 3  000143baebad4467a23b98c918ccda19     931  2021-01-31 22:12:00  1873448
# 4  000143baebad4467a23b98c918ccda19     931  2021-02-01 16:57:00  1873448

# %%
WEIGHTS = "./weights/SModel_0.606.pth"
device = "cuda:0"
model = SModel().to(device)
model = load_model(WEIGHTS, model, device)

# %%
mcc_code_to_idx, cat_code_to_idx = load_code_to_idx(
    "./submission/mcc_code_to_idx.pickle",
    "./submission/cat_code_to_idx.pickle",
)

# %%
vtb_emb = create_vtb_embeddings_for_model(
    transactions, model, mcc_code_to_idx, device
)
# Out:
# vtb embs shape:  (22533, 256)

# %%
rtk_emb = create_rtk_embeddings_for_model(
    clickstream, model, cat_code_to_idx, device
)
# Out:
# rtk embs shape:  (19623, 256)

# %% [markdown]
# ## Prepare train df:

# %%
train_match = pd.read_csv(TRAIN_MATCHING_PATH)


tgt = np.zeros(len(train_match))
tgt[:14671] = 1

train_match["tgt"] = tgt.astype(np.int16)
train_match.head()
# Out:
#                                bank                               rtk  tgt
# 0  178b387813ac4a63a2200274a9e3876e  e19c0f141e9442c5bdb0d5751f6fba1c    1
# 1  47cffa46e6b04389ba91a70735d2c3ff  7df3371aabd349e4ac2de8299238627d    1
# 2  f73b767cfd72472aa06df9a69e746aaf  b23d62c7e41145a7ad140a4fcfaafefa    1
# 3  48da649603734185b98dcea93484dbc7  63ad789541c54463ad54d0a707b3ab8b    1
# 4  37304ef19de542ee8fe8a6f050236525  c0e96de5dd594d948a8b9fde9e6980cb    1

# %%
rtk_ids = train_match[:14671].rtk.values

for i in range(14671, len(train_match)):
    train_match.loc[i, "rtk"] = np.random.choice(rtk_ids)

# %%
def get_negative_sample(match_true: pd.DataFrame, pos_sample: str) -> str:
    found = False
    while not found:
        sample = np.random.choice(match_true.rtk)
        if sample != pos_sample:
            return sample

# %%
N = len(train_match)
for i in tqdm(range(12000)):
    idx = np.random.randint(len(train_match[:14671]))
    vtb_id = train_match.iloc[idx].bank
    pos_id = train_match.iloc[idx].rtk
    neg_sample = get_negative_sample(train_match, pos_id)
    data = [vtb_id, neg_sample, 0]
    train_match.loc[N + i] = data
# Out:
# 100%|██████████| 12000/12000 [00:17<00:00, 680.66it/s]

# %%
sum(train_match.tgt == 1), sum(train_match.tgt == 0)
# Out:
# (14671, 14910)

# %%
train_match.head(-10)
# Out:
#                                    bank                               rtk  tgt
# 0      178b387813ac4a63a2200274a9e3876e  e19c0f141e9442c5bdb0d5751f6fba1c    1
# 1      47cffa46e6b04389ba91a70735d2c3ff  7df3371aabd349e4ac2de8299238627d    1
# 2      f73b767cfd72472aa06df9a69e746aaf  b23d62c7e41145a7ad140a4fcfaafefa    1
# 3      48da649603734185b98dcea93484dbc7  63ad789541c54463ad54d0a707b3ab8b    1
# 4      37304ef19de542ee8fe8a6f050236525  c0e96de5dd594d948a8b9fde9e6980cb    1
# ...                                 ...                               ...  ...
# 29566  69e2a51e498340218dac121b8e095d0b  23f446e84f3c4fb3abc82712856c7623    0
# 29567  405fef9c60c441c1957aa3ae865b7822  1bf1c3919d834aa5aa0e01eb708b8382    0
# 29568  c48fb7c619cf45b59afc9a163e6ee48c  63e5fe68837b4bd3b9d10fa6f67a18b5    0
# 29569  95cd33c2f87d42c381c394dc2e61f0e0  a1c263b422894d059f945fc618062fea    0
# 29570  666fbaaa40ea4142b3dcff99c4614fa5  1b9db776bddf44f7980529f847292ede    0
#
# [29571 rows x 3 columns]

# %% [markdown]
# ## Prepare train test split:

# %%
X = []
for i in train_match.index:
    vtb_id = train_match.iloc[i].bank
    rtk_id = train_match.iloc[i].rtk
    vtb_emb_ = vtb_emb[vtb_id]
    rtk_emb_ = rtk_emb[rtk_id]
    x = np.concatenate([vtb_emb_, rtk_emb_])
    X.append(x)

X = np.vstack(X)
y = train_match.tgt.values

print(X.shape)
print(y.shape)
# Out:
# (29581, 512)
# (29581,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, stratify=y, random_state=42, test_size=0.2
)

print(len(X_train), len(y_train))
print(len(X_test), len(y_test))
# Out:
# 23664 23664
# 5917 5917

# %% [markdown]
# ## Train XGBoost classifier:

# %%
import xgboost as xgb

# %%
# training, we set the early stopping rounds parameter
xgb_cl = xgb.XGBClassifier(
    n_estimators=10000,
    max_depth=4,
    learning_rate=0.01,
    subsample=0.8,
    gamma=0.5,
    reg_lambda=10,
    reg_alpha=5,
    colsample_bytree=1
)

xgb_cl.fit(
    X_train,
    y_train,
    eval_set=[(X_train, y_train), (X_test, y_test)],
    early_stopping_rounds=20,
)
# Out:
# /home/glebk/VSProjects/venvs/matching/lib/python3.8/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-logloss:0.69261	validation_1-logloss:0.69271
# [1]	validation_0-logloss:0.69222	validation_1-logloss:0.69241
# [2]	validation_0-logloss:0.69175	validation_1-logloss:0.69204
# [3]	validation_0-logloss:0.69117	validation_1-logloss:0.69164
# [4]	validation_0-logloss:0.69059	validation_1-logloss:0.69120
# [5]	validation_0-logloss:0.69027	validation_1-logloss:0.69100
# [6]	validation_0-logloss:0.68989	validation_1-logloss:0.69072
# [7]	validation_0-logloss:0.68939	validation_1-logloss:0.69037
# [8]	validation_0-logloss:0.68890	validation_1-logloss:0.69000
# [9]	validation_0-logloss:0.68851	validation_1-logloss:0.68970
# [10]	validation_0-logloss:0.68816	validation_1-logloss:0.68943
# [11]	validation_0-logloss:0.68785	validation_1-logloss:0.68919
# [12]	validation_0-logloss:0.68722	validation_1-logloss:0.68868
# [13]	validation_0-logloss:0.68683	validation_1-logloss:0.68842
# [14]	validation_0-logloss:0.68630	validation_1-logloss:0.68803
# [15]	validation_0-logloss:0.68596	validation_1-logloss:0.68784
# [16]	validation_0-logloss:0.68553	validation_1-logloss:0.68746
# [17]	validation_0-logloss:0.68517	validation_1-logloss:0.68716
# [18]	validation_0-logloss:0.68462	validation_1-logloss:0.68670
# [19]	validation_0-logloss:0.68429	validation_1-logloss:0.68644
# [20]	validation_0-logloss:0.68396	validation_1-logloss:0.68622
# [21]	validation_0-logloss:0.68361	validation_1-logloss:0.68601
# [22]	validation_0-logloss:0.68324	validation_1-logloss:0.68573
# [23]	validation_0-logloss:0.68273	validation_1-logloss:0.68532
# [24]	validation_0-logloss:0.68246	validation_1-logloss:0.68516
# [25]	validation_0-logloss:0.68195	validation_1-logloss:0.68481
# [26]	validation_0-logloss:0.68143	validation_1-logloss:0.68441
# [27]	validation_0-logloss:0.68114	validation_1-logloss:0.68422
# [28]	validation_0-logloss:0.68066	validation_1-logloss:0.68389
# [29]	validation_0-logloss:0.68032	validation_1-logloss:0.68364
# [30]	validation_0-logloss:0.67983	validation_1-logloss:0.68327
# [31]	validation_0-logloss:0.67923	validation_1-logloss:0.68283
# [32]	validation_0-logloss:0.67893	validation_1-logloss:0.68261
# [33]	validation_0-logloss:0.67849	validation_1-logloss:0.68224
# [34]	validation_0-logloss:0.67819	validation_1-logloss:0.68204
# [35]	validation_0-logloss:0.67789	validation_1-logloss:0.68184
# [36]	validation_0-logloss:0.67742	validation_1-logloss:0.68145
# [37]	validation_0-logloss:0.67695	validation_1-logloss:0.68108
# [38]	validation_0-logloss:0.67667	validation_1-logloss:0.68088
# [39]	validation_0-logloss:0.67633	validation_1-logloss:0.68066
# [40]	validation_0-logloss:0.67602	validation_1-logloss:0.68047
# [41]	validation_0-logloss:0.67556	validation_1-logloss:0.68010
# [42]	validation_0-logloss:0.67520	validation_1-logloss:0.67983
# [43]	validation_0-logloss:0.67476	validation_1-logloss:0.67955
# [44]	validation_0-logloss:0.67439	validation_1-logloss:0.67926
# [45]	validation_0-logloss:0.67400	validation_1-logloss:0.67895
# [46]	validation_0-logloss:0.67370	validation_1-logloss:0.67876
# [47]	validation_0-logloss:0.67325	validation_1-logloss:0.67846
# [48]	validation_0-logloss:0.67302	validation_1-logloss:0.67828
# [49]	validation_0-logloss:0.67269	validation_1-logloss:0.67799
# [50]	validation_0-logloss:0.67229	validation_1-logloss:0.67767
# [51]	validation_0-logloss:0.67200	validation_1-logloss:0.67747
# [52]	validation_0-logloss:0.67167	validation_1-logloss:0.67722
# [53]	validation_0-logloss:0.67134	validation_1-logloss:0.67698
# [54]	validation_0-logloss:0.67093	validation_1-logloss:0.67671
# [55]	validation_0-logloss:0.67048	validation_1-logloss:0.67636
# [56]	validation_0-logloss:0.67023	validation_1-logloss:0.67619
# [57]	validation_0-logloss:0.66980	validation_1-logloss:0.67588
# [58]	validation_0-logloss:0.66955	validation_1-logloss:0.67571
# [59]	validation_0-logloss:0.66921	validation_1-logloss:0.67548
# [60]	validation_0-logloss:0.66882	validation_1-logloss:0.67518
# [61]	validation_0-logloss:0.66841	validation_1-logloss:0.67488
# [62]	validation_0-logloss:0.66796	validation_1-logloss:0.67453
# [63]	validation_0-logloss:0.66749	validation_1-logloss:0.67418
# [64]	validation_0-logloss:0.66722	validation_1-logloss:0.67399
# [65]	validation_0-logloss:0.66697	validation_1-logloss:0.67382
# [66]	validation_0-logloss:0.66665	validation_1-logloss:0.67355
# [67]	validation_0-logloss:0.66637	validation_1-logloss:0.67336
# [68]	validation_0-logloss:0.66614	validation_1-logloss:0.67320
# [69]	validation_0-logloss:0.66569	validation_1-logloss:0.67286
# [70]	validation_0-logloss:0.66542	validation_1-logloss:0.67269
# [71]	validation_0-logloss:0.66512	validation_1-logloss:0.67249
# [72]	validation_0-logloss:0.66483	validation_1-logloss:0.67231
# [73]	validation_0-logloss:0.66447	validation_1-logloss:0.67203
# [74]	validation_0-logloss:0.66421	validation_1-logloss:0.67185
# [75]	validation_0-logloss:0.66378	validation_1-logloss:0.67154
# [76]	validation_0-logloss:0.66341	validation_1-logloss:0.67123
# [77]	validation_0-logloss:0.66303	validation_1-logloss:0.67097
# [78]	validation_0-logloss:0.66285	validation_1-logloss:0.67084
# [79]	validation_0-logloss:0.66256	validation_1-logloss:0.67064
# [80]	validation_0-logloss:0.66227	validation_1-logloss:0.67043
# [81]	validation_0-logloss:0.66194	validation_1-logloss:0.67016
# [82]	validation_0-logloss:0.66171	validation_1-logloss:0.67000
# [83]	validation_0-logloss:0.66145	validation_1-logloss:0.66982
# [84]	validation_0-logloss:0.66121	validation_1-logloss:0.66966
# [85]	validation_0-logloss:0.66097	validation_1-logloss:0.66949
# [86]	validation_0-logloss:0.66059	validation_1-logloss:0.66922
# [87]	validation_0-logloss:0.66029	validation_1-logloss:0.66897
# [88]	validation_0-logloss:0.65991	validation_1-logloss:0.66870
# [89]	validation_0-logloss:0.65958	validation_1-logloss:0.66846
# [90]	validation_0-logloss:0.65923	validation_1-logloss:0.66816
# [91]	validation_0-logloss:0.65895	validation_1-logloss:0.66795
# [92]	validation_0-logloss:0.65870	validation_1-logloss:0.66779
# [93]	validation_0-logloss:0.65843	validation_1-logloss:0.66757
# [94]	validation_0-logloss:0.65816	validation_1-logloss:0.66738
# [95]	validation_0-logloss:0.65778	validation_1-logloss:0.66707
# [96]	validation_0-logloss:0.65747	validation_1-logloss:0.66682
# [97]	validation_0-logloss:0.65708	validation_1-logloss:0.66653
# [98]	validation_0-logloss:0.65682	validation_1-logloss:0.66635
# [99]	validation_0-logloss:0.65644	validation_1-logloss:0.66603
# [100]	validation_0-logloss:0.65601	validation_1-logloss:0.66571
# [101]	validation_0-logloss:0.65571	validation_1-logloss:0.66547
# [102]	validation_0-logloss:0.65547	validation_1-logloss:0.66533
# [103]	validation_0-logloss:0.65513	validation_1-logloss:0.66506
# [104]	validation_0-logloss:0.65482	validation_1-logloss:0.66481
# [105]	validation_0-logloss:0.65460	validation_1-logloss:0.66466
# [106]	validation_0-logloss:0.65428	validation_1-logloss:0.66442
# [107]	validation_0-logloss:0.65402	validation_1-logloss:0.66422
# [108]	validation_0-logloss:0.65367	validation_1-logloss:0.66397
# [109]	validation_0-logloss:0.65329	validation_1-logloss:0.66368
# [110]	validation_0-logloss:0.65298	validation_1-logloss:0.66347
# [111]	validation_0-logloss:0.65274	validation_1-logloss:0.66328
# [112]	validation_0-logloss:0.65242	validation_1-logloss:0.66305
# [113]	validation_0-logloss:0.65218	validation_1-logloss:0.66288
# [114]	validation_0-logloss:0.65194	validation_1-logloss:0.66269
# [115]	validation_0-logloss:0.65164	validation_1-logloss:0.66244
# [116]	validation_0-logloss:0.65131	validation_1-logloss:0.66220
# [117]	validation_0-logloss:0.65117	validation_1-logloss:0.66214
# [118]	validation_0-logloss:0.65095	validation_1-logloss:0.66201
# [119]	validation_0-logloss:0.65070	validation_1-logloss:0.66184
# [120]	validation_0-logloss:0.65035	validation_1-logloss:0.66155
# [121]	validation_0-logloss:0.64996	validation_1-logloss:0.66123
# [122]	validation_0-logloss:0.64957	validation_1-logloss:0.66095
# [123]	validation_0-logloss:0.64938	validation_1-logloss:0.66083
# [124]	validation_0-logloss:0.64918	validation_1-logloss:0.66070
# [125]	validation_0-logloss:0.64898	validation_1-logloss:0.66060
# [126]	validation_0-logloss:0.64871	validation_1-logloss:0.66040
# [127]	validation_0-logloss:0.64845	validation_1-logloss:0.66025
# [128]	validation_0-logloss:0.64808	validation_1-logloss:0.65998
# [129]	validation_0-logloss:0.64777	validation_1-logloss:0.65973
# [130]	validation_0-logloss:0.64752	validation_1-logloss:0.65955
# [131]	validation_0-logloss:0.64727	validation_1-logloss:0.65937
# [132]	validation_0-logloss:0.64701	validation_1-logloss:0.65918
# [133]	validation_0-logloss:0.64677	validation_1-logloss:0.65900
# [134]	validation_0-logloss:0.64641	validation_1-logloss:0.65873
# [135]	validation_0-logloss:0.64621	validation_1-logloss:0.65861
# [136]	validation_0-logloss:0.64593	validation_1-logloss:0.65841
# [137]	validation_0-logloss:0.64568	validation_1-logloss:0.65824
# [138]	validation_0-logloss:0.64537	validation_1-logloss:0.65801
# [139]	validation_0-logloss:0.64499	validation_1-logloss:0.65771
# [140]	validation_0-logloss:0.64479	validation_1-logloss:0.65754
# [141]	validation_0-logloss:0.64455	validation_1-logloss:0.65740
# [142]	validation_0-logloss:0.64429	validation_1-logloss:0.65722
# [143]	validation_0-logloss:0.64405	validation_1-logloss:0.65702
# [144]	validation_0-logloss:0.64383	validation_1-logloss:0.65686
# [145]	validation_0-logloss:0.64365	validation_1-logloss:0.65676
# [146]	validation_0-logloss:0.64340	validation_1-logloss:0.65655
# [147]	validation_0-logloss:0.64324	validation_1-logloss:0.65645
# [148]	validation_0-logloss:0.64301	validation_1-logloss:0.65631
# [149]	validation_0-logloss:0.64278	validation_1-logloss:0.65619
# [150]	validation_0-logloss:0.64253	validation_1-logloss:0.65600
# [151]	validation_0-logloss:0.64233	validation_1-logloss:0.65584
# [152]	validation_0-logloss:0.64211	validation_1-logloss:0.65569
# [153]	validation_0-logloss:0.64187	validation_1-logloss:0.65551
# [154]	validation_0-logloss:0.64168	validation_1-logloss:0.65538
# [155]	validation_0-logloss:0.64138	validation_1-logloss:0.65515
# [156]	validation_0-logloss:0.64126	validation_1-logloss:0.65507
# [157]	validation_0-logloss:0.64102	validation_1-logloss:0.65496
# [158]	validation_0-logloss:0.64069	validation_1-logloss:0.65472
# [159]	validation_0-logloss:0.64043	validation_1-logloss:0.65447
# [160]	validation_0-logloss:0.64006	validation_1-logloss:0.65418
# [161]	validation_0-logloss:0.63988	validation_1-logloss:0.65406
# [162]	validation_0-logloss:0.63954	validation_1-logloss:0.65381
# [163]	validation_0-logloss:0.63937	validation_1-logloss:0.65367
# [164]	validation_0-logloss:0.63918	validation_1-logloss:0.65355
# [165]	validation_0-logloss:0.63901	validation_1-logloss:0.65342
# [166]	validation_0-logloss:0.63876	validation_1-logloss:0.65326
# [167]	validation_0-logloss:0.63840	validation_1-logloss:0.65297
# [168]	validation_0-logloss:0.63825	validation_1-logloss:0.65287
# [169]	validation_0-logloss:0.63799	validation_1-logloss:0.65269
# [170]	validation_0-logloss:0.63773	validation_1-logloss:0.65249
# [171]	validation_0-logloss:0.63755	validation_1-logloss:0.65239
# [172]	validation_0-logloss:0.63728	validation_1-logloss:0.65218
# [173]	validation_0-logloss:0.63707	validation_1-logloss:0.65204
# [174]	validation_0-logloss:0.63673	validation_1-logloss:0.65179
# [175]	validation_0-logloss:0.63655	validation_1-logloss:0.65165
# [176]	validation_0-logloss:0.63631	validation_1-logloss:0.65147
# [177]	validation_0-logloss:0.63609	validation_1-logloss:0.65134
# [178]	validation_0-logloss:0.63590	validation_1-logloss:0.65121
# [179]	validation_0-logloss:0.63566	validation_1-logloss:0.65104
# [180]	validation_0-logloss:0.63549	validation_1-logloss:0.65093
# [181]	validation_0-logloss:0.63526	validation_1-logloss:0.65077
# [182]	validation_0-logloss:0.63509	validation_1-logloss:0.65067
# [183]	validation_0-logloss:0.63490	validation_1-logloss:0.65053
# [184]	validation_0-logloss:0.63471	validation_1-logloss:0.65042
# [185]	validation_0-logloss:0.63448	validation_1-logloss:0.65024
# [186]	validation_0-logloss:0.63427	validation_1-logloss:0.65012
# [187]	validation_0-logloss:0.63397	validation_1-logloss:0.64990
# [188]	validation_0-logloss:0.63375	validation_1-logloss:0.64976
# [189]	validation_0-logloss:0.63358	validation_1-logloss:0.64963
# [190]	validation_0-logloss:0.63332	validation_1-logloss:0.64944
# [191]	validation_0-logloss:0.63312	validation_1-logloss:0.64930
# [192]	validation_0-logloss:0.63287	validation_1-logloss:0.64912
# [193]	validation_0-logloss:0.63277	validation_1-logloss:0.64906
# [194]	validation_0-logloss:0.63254	validation_1-logloss:0.64890
# [195]	validation_0-logloss:0.63242	validation_1-logloss:0.64884
# [196]	validation_0-logloss:0.63225	validation_1-logloss:0.64872
# [197]	validation_0-logloss:0.63200	validation_1-logloss:0.64850
# [198]	validation_0-logloss:0.63168	validation_1-logloss:0.64830
# [199]	validation_0-logloss:0.63149	validation_1-logloss:0.64818
# [200]	validation_0-logloss:0.63131	validation_1-logloss:0.64803
# [201]	validation_0-logloss:0.63103	validation_1-logloss:0.64782
# [202]	validation_0-logloss:0.63082	validation_1-logloss:0.64768
# [203]	validation_0-logloss:0.63065	validation_1-logloss:0.64755
# [204]	validation_0-logloss:0.63038	validation_1-logloss:0.64734
# [205]	validation_0-logloss:0.63016	validation_1-logloss:0.64719
# [206]	validation_0-logloss:0.62996	validation_1-logloss:0.64704
# [207]	validation_0-logloss:0.62977	validation_1-logloss:0.64694
# [208]	validation_0-logloss:0.62957	validation_1-logloss:0.64680
# [209]	validation_0-logloss:0.62940	validation_1-logloss:0.64668
# [210]	validation_0-logloss:0.62920	validation_1-logloss:0.64655
# [211]	validation_0-logloss:0.62896	validation_1-logloss:0.64642
# [212]	validation_0-logloss:0.62866	validation_1-logloss:0.64619
# [213]	validation_0-logloss:0.62835	validation_1-logloss:0.64597
# [214]	validation_0-logloss:0.62817	validation_1-logloss:0.64585
# [215]	validation_0-logloss:0.62785	validation_1-logloss:0.64562
# [216]	validation_0-logloss:0.62757	validation_1-logloss:0.64541
# [217]	validation_0-logloss:0.62743	validation_1-logloss:0.64532
# [218]	validation_0-logloss:0.62727	validation_1-logloss:0.64521
# [219]	validation_0-logloss:0.62710	validation_1-logloss:0.64512
# [220]	validation_0-logloss:0.62689	validation_1-logloss:0.64495
# [221]	validation_0-logloss:0.62669	validation_1-logloss:0.64480
# [222]	validation_0-logloss:0.62643	validation_1-logloss:0.64460
# [223]	validation_0-logloss:0.62625	validation_1-logloss:0.64449
# [224]	validation_0-logloss:0.62607	validation_1-logloss:0.64436
# [225]	validation_0-logloss:0.62595	validation_1-logloss:0.64429
# [226]	validation_0-logloss:0.62567	validation_1-logloss:0.64409
# [227]	validation_0-logloss:0.62542	validation_1-logloss:0.64393
# [228]	validation_0-logloss:0.62528	validation_1-logloss:0.64383
# [229]	validation_0-logloss:0.62504	validation_1-logloss:0.64363
# [230]	validation_0-logloss:0.62474	validation_1-logloss:0.64342
# [231]	validation_0-logloss:0.62457	validation_1-logloss:0.64332
# [232]	validation_0-logloss:0.62429	validation_1-logloss:0.64311
# [233]	validation_0-logloss:0.62407	validation_1-logloss:0.64294
# [234]	validation_0-logloss:0.62391	validation_1-logloss:0.64284
# [235]	validation_0-logloss:0.62363	validation_1-logloss:0.64261
# [236]	validation_0-logloss:0.62354	validation_1-logloss:0.64258
# [237]	validation_0-logloss:0.62335	validation_1-logloss:0.64245
# [238]	validation_0-logloss:0.62314	validation_1-logloss:0.64231
# [239]	validation_0-logloss:0.62296	validation_1-logloss:0.64220
# [240]	validation_0-logloss:0.62275	validation_1-logloss:0.64206
# [241]	validation_0-logloss:0.62270	validation_1-logloss:0.64204
# [242]	validation_0-logloss:0.62247	validation_1-logloss:0.64191
# [243]	validation_0-logloss:0.62215	validation_1-logloss:0.64165
# [244]	validation_0-logloss:0.62196	validation_1-logloss:0.64151
# [245]	validation_0-logloss:0.62179	validation_1-logloss:0.64141
# [246]	validation_0-logloss:0.62157	validation_1-logloss:0.64130
# [247]	validation_0-logloss:0.62137	validation_1-logloss:0.64115
# [248]	validation_0-logloss:0.62120	validation_1-logloss:0.64105
# [249]	validation_0-logloss:0.62110	validation_1-logloss:0.64097
# [250]	validation_0-logloss:0.62094	validation_1-logloss:0.64083
# [251]	validation_0-logloss:0.62079	validation_1-logloss:0.64075
# [252]	validation_0-logloss:0.62057	validation_1-logloss:0.64059
# [253]	validation_0-logloss:0.62044	validation_1-logloss:0.64049
# [254]	validation_0-logloss:0.62023	validation_1-logloss:0.64033
# [255]	validation_0-logloss:0.62008	validation_1-logloss:0.64026
# [256]	validation_0-logloss:0.61993	validation_1-logloss:0.64015
# [257]	validation_0-logloss:0.61967	validation_1-logloss:0.64000
# [258]	validation_0-logloss:0.61948	validation_1-logloss:0.63987
# [259]	validation_0-logloss:0.61929	validation_1-logloss:0.63974
# [260]	validation_0-logloss:0.61909	validation_1-logloss:0.63959
# [261]	validation_0-logloss:0.61889	validation_1-logloss:0.63944
# [262]	validation_0-logloss:0.61864	validation_1-logloss:0.63928
# [263]	validation_0-logloss:0.61847	validation_1-logloss:0.63918
# [264]	validation_0-logloss:0.61831	validation_1-logloss:0.63911
# [265]	validation_0-logloss:0.61818	validation_1-logloss:0.63902
# [266]	validation_0-logloss:0.61803	validation_1-logloss:0.63893
# [267]	validation_0-logloss:0.61785	validation_1-logloss:0.63879
# [268]	validation_0-logloss:0.61768	validation_1-logloss:0.63867
# [269]	validation_0-logloss:0.61753	validation_1-logloss:0.63859
# [270]	validation_0-logloss:0.61736	validation_1-logloss:0.63848
# [271]	validation_0-logloss:0.61719	validation_1-logloss:0.63839
# [272]	validation_0-logloss:0.61707	validation_1-logloss:0.63830
# [273]	validation_0-logloss:0.61685	validation_1-logloss:0.63816
# [274]	validation_0-logloss:0.61672	validation_1-logloss:0.63806
# [275]	validation_0-logloss:0.61654	validation_1-logloss:0.63794
# [276]	validation_0-logloss:0.61640	validation_1-logloss:0.63786
# [277]	validation_0-logloss:0.61629	validation_1-logloss:0.63779
# [278]	validation_0-logloss:0.61618	validation_1-logloss:0.63772
# [279]	validation_0-logloss:0.61600	validation_1-logloss:0.63760
# [280]	validation_0-logloss:0.61581	validation_1-logloss:0.63746
# [281]	validation_0-logloss:0.61567	validation_1-logloss:0.63739
# [282]	validation_0-logloss:0.61551	validation_1-logloss:0.63729
# [283]	validation_0-logloss:0.61535	validation_1-logloss:0.63718
# [284]	validation_0-logloss:0.61519	validation_1-logloss:0.63707
# [285]	validation_0-logloss:0.61500	validation_1-logloss:0.63690
# [286]	validation_0-logloss:0.61481	validation_1-logloss:0.63679
# [287]	validation_0-logloss:0.61469	validation_1-logloss:0.63671
# [288]	validation_0-logloss:0.61452	validation_1-logloss:0.63659
# [289]	validation_0-logloss:0.61430	validation_1-logloss:0.63648
# [290]	validation_0-logloss:0.61404	validation_1-logloss:0.63632
# [291]	validation_0-logloss:0.61395	validation_1-logloss:0.63626
# [292]	validation_0-logloss:0.61377	validation_1-logloss:0.63616
# [293]	validation_0-logloss:0.61363	validation_1-logloss:0.63608
# [294]	validation_0-logloss:0.61341	validation_1-logloss:0.63597
# [295]	validation_0-logloss:0.61323	validation_1-logloss:0.63584
# [296]	validation_0-logloss:0.61299	validation_1-logloss:0.63567
# [297]	validation_0-logloss:0.61286	validation_1-logloss:0.63556
# [298]	validation_0-logloss:0.61267	validation_1-logloss:0.63541
# [299]	validation_0-logloss:0.61248	validation_1-logloss:0.63527
# [300]	validation_0-logloss:0.61229	validation_1-logloss:0.63513
# [301]	validation_0-logloss:0.61211	validation_1-logloss:0.63498
# [302]	validation_0-logloss:0.61191	validation_1-logloss:0.63484
# [303]	validation_0-logloss:0.61180	validation_1-logloss:0.63477
# [304]	validation_0-logloss:0.61161	validation_1-logloss:0.63466
# [305]	validation_0-logloss:0.61145	validation_1-logloss:0.63456
# [306]	validation_0-logloss:0.61137	validation_1-logloss:0.63451
# [307]	validation_0-logloss:0.61117	validation_1-logloss:0.63438
# [308]	validation_0-logloss:0.61101	validation_1-logloss:0.63430
# [309]	validation_0-logloss:0.61088	validation_1-logloss:0.63422
# [310]	validation_0-logloss:0.61070	validation_1-logloss:0.63414
# [311]	validation_0-logloss:0.61051	validation_1-logloss:0.63402
# [312]	validation_0-logloss:0.61033	validation_1-logloss:0.63390
# [313]	validation_0-logloss:0.61019	validation_1-logloss:0.63382
# [314]	validation_0-logloss:0.61000	validation_1-logloss:0.63370
# [315]	validation_0-logloss:0.60983	validation_1-logloss:0.63359
# [316]	validation_0-logloss:0.60963	validation_1-logloss:0.63345
# [317]	validation_0-logloss:0.60945	validation_1-logloss:0.63333
# [318]	validation_0-logloss:0.60934	validation_1-logloss:0.63327
# [319]	validation_0-logloss:0.60915	validation_1-logloss:0.63314
# [320]	validation_0-logloss:0.60903	validation_1-logloss:0.63305
# [321]	validation_0-logloss:0.60879	validation_1-logloss:0.63284
# [322]	validation_0-logloss:0.60864	validation_1-logloss:0.63274
# [323]	validation_0-logloss:0.60845	validation_1-logloss:0.63260
# [324]	validation_0-logloss:0.60823	validation_1-logloss:0.63243
# [325]	validation_0-logloss:0.60802	validation_1-logloss:0.63233
# [326]	validation_0-logloss:0.60783	validation_1-logloss:0.63220
# [327]	validation_0-logloss:0.60774	validation_1-logloss:0.63214
# [328]	validation_0-logloss:0.60751	validation_1-logloss:0.63199
# [329]	validation_0-logloss:0.60730	validation_1-logloss:0.63182
# [330]	validation_0-logloss:0.60719	validation_1-logloss:0.63175
# [331]	validation_0-logloss:0.60696	validation_1-logloss:0.63160
# [332]	validation_0-logloss:0.60682	validation_1-logloss:0.63148
# [333]	validation_0-logloss:0.60667	validation_1-logloss:0.63140
# [334]	validation_0-logloss:0.60645	validation_1-logloss:0.63127
# [335]	validation_0-logloss:0.60629	validation_1-logloss:0.63118
# [336]	validation_0-logloss:0.60613	validation_1-logloss:0.63110
# [337]	validation_0-logloss:0.60596	validation_1-logloss:0.63100
# [338]	validation_0-logloss:0.60582	validation_1-logloss:0.63091
# [339]	validation_0-logloss:0.60559	validation_1-logloss:0.63074
# [340]	validation_0-logloss:0.60544	validation_1-logloss:0.63066
# [341]	validation_0-logloss:0.60527	validation_1-logloss:0.63056
# [342]	validation_0-logloss:0.60507	validation_1-logloss:0.63041
# [343]	validation_0-logloss:0.60489	validation_1-logloss:0.63027
# [344]	validation_0-logloss:0.60473	validation_1-logloss:0.63013
# [345]	validation_0-logloss:0.60461	validation_1-logloss:0.63006
# [346]	validation_0-logloss:0.60445	validation_1-logloss:0.62995
# [347]	validation_0-logloss:0.60427	validation_1-logloss:0.62984
# [348]	validation_0-logloss:0.60415	validation_1-logloss:0.62977
# [349]	validation_0-logloss:0.60401	validation_1-logloss:0.62967
# [350]	validation_0-logloss:0.60391	validation_1-logloss:0.62963
# [351]	validation_0-logloss:0.60372	validation_1-logloss:0.62952
# [352]	validation_0-logloss:0.60353	validation_1-logloss:0.62938
# [353]	validation_0-logloss:0.60340	validation_1-logloss:0.62932
# [354]	validation_0-logloss:0.60325	validation_1-logloss:0.62921
# [355]	validation_0-logloss:0.60308	validation_1-logloss:0.62909
# [356]	validation_0-logloss:0.60296	validation_1-logloss:0.62903
# [357]	validation_0-logloss:0.60286	validation_1-logloss:0.62895
# [358]	validation_0-logloss:0.60279	validation_1-logloss:0.62891
# [359]	validation_0-logloss:0.60261	validation_1-logloss:0.62881
# [360]	validation_0-logloss:0.60242	validation_1-logloss:0.62864
# [361]	validation_0-logloss:0.60225	validation_1-logloss:0.62854
# [362]	validation_0-logloss:0.60214	validation_1-logloss:0.62847
# [363]	validation_0-logloss:0.60202	validation_1-logloss:0.62840
# [364]	validation_0-logloss:0.60182	validation_1-logloss:0.62825
# [365]	validation_0-logloss:0.60169	validation_1-logloss:0.62818
# [366]	validation_0-logloss:0.60159	validation_1-logloss:0.62809
# [367]	validation_0-logloss:0.60140	validation_1-logloss:0.62793
# [368]	validation_0-logloss:0.60130	validation_1-logloss:0.62785
# [369]	validation_0-logloss:0.60116	validation_1-logloss:0.62776
# [370]	validation_0-logloss:0.60103	validation_1-logloss:0.62769
# [371]	validation_0-logloss:0.60088	validation_1-logloss:0.62761
# [372]	validation_0-logloss:0.60067	validation_1-logloss:0.62746
# [373]	validation_0-logloss:0.60047	validation_1-logloss:0.62732
# [374]	validation_0-logloss:0.60032	validation_1-logloss:0.62720
# [375]	validation_0-logloss:0.60017	validation_1-logloss:0.62710
# [376]	validation_0-logloss:0.60002	validation_1-logloss:0.62702
# [377]	validation_0-logloss:0.59992	validation_1-logloss:0.62696
# [378]	validation_0-logloss:0.59978	validation_1-logloss:0.62688
# [379]	validation_0-logloss:0.59956	validation_1-logloss:0.62672
# [380]	validation_0-logloss:0.59948	validation_1-logloss:0.62668
# [381]	validation_0-logloss:0.59931	validation_1-logloss:0.62655
# [382]	validation_0-logloss:0.59912	validation_1-logloss:0.62642
# [383]	validation_0-logloss:0.59896	validation_1-logloss:0.62632
# [384]	validation_0-logloss:0.59876	validation_1-logloss:0.62617
# [385]	validation_0-logloss:0.59858	validation_1-logloss:0.62609
# [386]	validation_0-logloss:0.59845	validation_1-logloss:0.62604
# [387]	validation_0-logloss:0.59832	validation_1-logloss:0.62596
# [388]	validation_0-logloss:0.59816	validation_1-logloss:0.62584
# [389]	validation_0-logloss:0.59803	validation_1-logloss:0.62573
# [390]	validation_0-logloss:0.59785	validation_1-logloss:0.62560
# [391]	validation_0-logloss:0.59773	validation_1-logloss:0.62552
# [392]	validation_0-logloss:0.59760	validation_1-logloss:0.62546
# [393]	validation_0-logloss:0.59745	validation_1-logloss:0.62537
# [394]	validation_0-logloss:0.59732	validation_1-logloss:0.62528
# [395]	validation_0-logloss:0.59719	validation_1-logloss:0.62520
# [396]	validation_0-logloss:0.59703	validation_1-logloss:0.62510
# [397]	validation_0-logloss:0.59688	validation_1-logloss:0.62500
# [398]	validation_0-logloss:0.59674	validation_1-logloss:0.62489
# [399]	validation_0-logloss:0.59657	validation_1-logloss:0.62479
# [400]	validation_0-logloss:0.59647	validation_1-logloss:0.62475
# [401]	validation_0-logloss:0.59634	validation_1-logloss:0.62466
# [402]	validation_0-logloss:0.59617	validation_1-logloss:0.62456
# [403]	validation_0-logloss:0.59600	validation_1-logloss:0.62445
# [404]	validation_0-logloss:0.59580	validation_1-logloss:0.62430
# [405]	validation_0-logloss:0.59570	validation_1-logloss:0.62425
# [406]	validation_0-logloss:0.59550	validation_1-logloss:0.62412
# [407]	validation_0-logloss:0.59540	validation_1-logloss:0.62408
# [408]	validation_0-logloss:0.59525	validation_1-logloss:0.62398
# [409]	validation_0-logloss:0.59508	validation_1-logloss:0.62387
# [410]	validation_0-logloss:0.59490	validation_1-logloss:0.62375
# [411]	validation_0-logloss:0.59477	validation_1-logloss:0.62369
# [412]	validation_0-logloss:0.59466	validation_1-logloss:0.62365
# [413]	validation_0-logloss:0.59448	validation_1-logloss:0.62356
# [414]	validation_0-logloss:0.59427	validation_1-logloss:0.62338
# [415]	validation_0-logloss:0.59414	validation_1-logloss:0.62330
# [416]	validation_0-logloss:0.59398	validation_1-logloss:0.62320
# [417]	validation_0-logloss:0.59388	validation_1-logloss:0.62316
# [418]	validation_0-logloss:0.59368	validation_1-logloss:0.62303
# [419]	validation_0-logloss:0.59353	validation_1-logloss:0.62294
# [420]	validation_0-logloss:0.59347	validation_1-logloss:0.62289
# [421]	validation_0-logloss:0.59330	validation_1-logloss:0.62282
# [422]	validation_0-logloss:0.59315	validation_1-logloss:0.62272
# [423]	validation_0-logloss:0.59303	validation_1-logloss:0.62267
# [424]	validation_0-logloss:0.59293	validation_1-logloss:0.62261
# [425]	validation_0-logloss:0.59277	validation_1-logloss:0.62253
# [426]	validation_0-logloss:0.59263	validation_1-logloss:0.62246
# [427]	validation_0-logloss:0.59250	validation_1-logloss:0.62237
# [428]	validation_0-logloss:0.59237	validation_1-logloss:0.62231
# [429]	validation_0-logloss:0.59222	validation_1-logloss:0.62220
# [430]	validation_0-logloss:0.59206	validation_1-logloss:0.62213
# [431]	validation_0-logloss:0.59188	validation_1-logloss:0.62201
# [432]	validation_0-logloss:0.59174	validation_1-logloss:0.62191
# [433]	validation_0-logloss:0.59159	validation_1-logloss:0.62182
# [434]	validation_0-logloss:0.59142	validation_1-logloss:0.62173
# [435]	validation_0-logloss:0.59124	validation_1-logloss:0.62161
# [436]	validation_0-logloss:0.59110	validation_1-logloss:0.62152
# [437]	validation_0-logloss:0.59098	validation_1-logloss:0.62144
# [438]	validation_0-logloss:0.59089	validation_1-logloss:0.62141
# [439]	validation_0-logloss:0.59073	validation_1-logloss:0.62131
# [440]	validation_0-logloss:0.59061	validation_1-logloss:0.62123
# [441]	validation_0-logloss:0.59045	validation_1-logloss:0.62113
# [442]	validation_0-logloss:0.59029	validation_1-logloss:0.62103
# [443]	validation_0-logloss:0.59016	validation_1-logloss:0.62096
# [444]	validation_0-logloss:0.59002	validation_1-logloss:0.62088
# [445]	validation_0-logloss:0.58988	validation_1-logloss:0.62080
# [446]	validation_0-logloss:0.58973	validation_1-logloss:0.62072
# [447]	validation_0-logloss:0.58955	validation_1-logloss:0.62060
# [448]	validation_0-logloss:0.58945	validation_1-logloss:0.62055
# [449]	validation_0-logloss:0.58930	validation_1-logloss:0.62046
# [450]	validation_0-logloss:0.58914	validation_1-logloss:0.62035
# [451]	validation_0-logloss:0.58896	validation_1-logloss:0.62021
# [452]	validation_0-logloss:0.58887	validation_1-logloss:0.62016
# [453]	validation_0-logloss:0.58875	validation_1-logloss:0.62009
# [454]	validation_0-logloss:0.58865	validation_1-logloss:0.62004
# [455]	validation_0-logloss:0.58858	validation_1-logloss:0.62001
# [456]	validation_0-logloss:0.58846	validation_1-logloss:0.61992
# [457]	validation_0-logloss:0.58829	validation_1-logloss:0.61981
# [458]	validation_0-logloss:0.58813	validation_1-logloss:0.61967
# [459]	validation_0-logloss:0.58797	validation_1-logloss:0.61958
# [460]	validation_0-logloss:0.58788	validation_1-logloss:0.61954
# [461]	validation_0-logloss:0.58776	validation_1-logloss:0.61945
# [462]	validation_0-logloss:0.58759	validation_1-logloss:0.61934
# [463]	validation_0-logloss:0.58741	validation_1-logloss:0.61922
# [464]	validation_0-logloss:0.58730	validation_1-logloss:0.61915
# [465]	validation_0-logloss:0.58714	validation_1-logloss:0.61906
# [466]	validation_0-logloss:0.58699	validation_1-logloss:0.61896
# [467]	validation_0-logloss:0.58684	validation_1-logloss:0.61887
# [468]	validation_0-logloss:0.58666	validation_1-logloss:0.61875
# [469]	validation_0-logloss:0.58652	validation_1-logloss:0.61866
# [470]	validation_0-logloss:0.58634	validation_1-logloss:0.61853
# [471]	validation_0-logloss:0.58629	validation_1-logloss:0.61854
# [472]	validation_0-logloss:0.58618	validation_1-logloss:0.61849
# [473]	validation_0-logloss:0.58607	validation_1-logloss:0.61845
# [474]	validation_0-logloss:0.58596	validation_1-logloss:0.61839
# [475]	validation_0-logloss:0.58582	validation_1-logloss:0.61832
# [476]	validation_0-logloss:0.58570	validation_1-logloss:0.61828
# [477]	validation_0-logloss:0.58560	validation_1-logloss:0.61821
# [478]	validation_0-logloss:0.58547	validation_1-logloss:0.61812
# [479]	validation_0-logloss:0.58534	validation_1-logloss:0.61802
# [480]	validation_0-logloss:0.58516	validation_1-logloss:0.61791
# [481]	validation_0-logloss:0.58505	validation_1-logloss:0.61783
# [482]	validation_0-logloss:0.58495	validation_1-logloss:0.61779
# [483]	validation_0-logloss:0.58482	validation_1-logloss:0.61770
# [484]	validation_0-logloss:0.58468	validation_1-logloss:0.61763
# [485]	validation_0-logloss:0.58455	validation_1-logloss:0.61757
# [486]	validation_0-logloss:0.58442	validation_1-logloss:0.61750
# [487]	validation_0-logloss:0.58423	validation_1-logloss:0.61738
# [488]	validation_0-logloss:0.58409	validation_1-logloss:0.61730
# [489]	validation_0-logloss:0.58395	validation_1-logloss:0.61719
# [490]	validation_0-logloss:0.58383	validation_1-logloss:0.61714
# [491]	validation_0-logloss:0.58375	validation_1-logloss:0.61710
# [492]	validation_0-logloss:0.58363	validation_1-logloss:0.61703
# [493]	validation_0-logloss:0.58350	validation_1-logloss:0.61694
# [494]	validation_0-logloss:0.58336	validation_1-logloss:0.61687
# [495]	validation_0-logloss:0.58327	validation_1-logloss:0.61682
# [496]	validation_0-logloss:0.58315	validation_1-logloss:0.61675
# [497]	validation_0-logloss:0.58298	validation_1-logloss:0.61663
# [498]	validation_0-logloss:0.58287	validation_1-logloss:0.61654
# [499]	validation_0-logloss:0.58273	validation_1-logloss:0.61645
# [500]	validation_0-logloss:0.58257	validation_1-logloss:0.61635
# [501]	validation_0-logloss:0.58247	validation_1-logloss:0.61630
# [502]	validation_0-logloss:0.58238	validation_1-logloss:0.61625
# [503]	validation_0-logloss:0.58231	validation_1-logloss:0.61622
# [504]	validation_0-logloss:0.58213	validation_1-logloss:0.61610
# [505]	validation_0-logloss:0.58203	validation_1-logloss:0.61603
# [506]	validation_0-logloss:0.58189	validation_1-logloss:0.61594
# [507]	validation_0-logloss:0.58180	validation_1-logloss:0.61588
# [508]	validation_0-logloss:0.58165	validation_1-logloss:0.61580
# [509]	validation_0-logloss:0.58150	validation_1-logloss:0.61569
# [510]	validation_0-logloss:0.58137	validation_1-logloss:0.61562
# [511]	validation_0-logloss:0.58124	validation_1-logloss:0.61553
# [512]	validation_0-logloss:0.58107	validation_1-logloss:0.61539
# [513]	validation_0-logloss:0.58097	validation_1-logloss:0.61532
# [514]	validation_0-logloss:0.58086	validation_1-logloss:0.61528
# [515]	validation_0-logloss:0.58072	validation_1-logloss:0.61519
# [516]	validation_0-logloss:0.58058	validation_1-logloss:0.61510
# [517]	validation_0-logloss:0.58044	validation_1-logloss:0.61502
# [518]	validation_0-logloss:0.58032	validation_1-logloss:0.61497
# [519]	validation_0-logloss:0.58017	validation_1-logloss:0.61487
# [520]	validation_0-logloss:0.58001	validation_1-logloss:0.61474
# [521]	validation_0-logloss:0.57993	validation_1-logloss:0.61468
# [522]	validation_0-logloss:0.57976	validation_1-logloss:0.61459
# [523]	validation_0-logloss:0.57968	validation_1-logloss:0.61456
# [524]	validation_0-logloss:0.57955	validation_1-logloss:0.61447
# [525]	validation_0-logloss:0.57941	validation_1-logloss:0.61437
# [526]	validation_0-logloss:0.57931	validation_1-logloss:0.61430
# [527]	validation_0-logloss:0.57917	validation_1-logloss:0.61424
# [528]	validation_0-logloss:0.57906	validation_1-logloss:0.61417
# [529]	validation_0-logloss:0.57893	validation_1-logloss:0.61408
# [530]	validation_0-logloss:0.57882	validation_1-logloss:0.61402
# [531]	validation_0-logloss:0.57865	validation_1-logloss:0.61391
# [532]	validation_0-logloss:0.57857	validation_1-logloss:0.61387
# [533]	validation_0-logloss:0.57844	validation_1-logloss:0.61379
# [534]	validation_0-logloss:0.57835	validation_1-logloss:0.61375
# [535]	validation_0-logloss:0.57819	validation_1-logloss:0.61365
# [536]	validation_0-logloss:0.57807	validation_1-logloss:0.61359
# [537]	validation_0-logloss:0.57795	validation_1-logloss:0.61351
# [538]	validation_0-logloss:0.57789	validation_1-logloss:0.61349
# [539]	validation_0-logloss:0.57779	validation_1-logloss:0.61343
# [540]	validation_0-logloss:0.57770	validation_1-logloss:0.61337
# [541]	validation_0-logloss:0.57756	validation_1-logloss:0.61329
# [542]	validation_0-logloss:0.57747	validation_1-logloss:0.61325
# [543]	validation_0-logloss:0.57737	validation_1-logloss:0.61320
# [544]	validation_0-logloss:0.57725	validation_1-logloss:0.61312
# [545]	validation_0-logloss:0.57717	validation_1-logloss:0.61308
# [546]	validation_0-logloss:0.57704	validation_1-logloss:0.61301
# [547]	validation_0-logloss:0.57698	validation_1-logloss:0.61297
# [548]	validation_0-logloss:0.57684	validation_1-logloss:0.61288
# [549]	validation_0-logloss:0.57674	validation_1-logloss:0.61282
# [550]	validation_0-logloss:0.57662	validation_1-logloss:0.61275
# [551]	validation_0-logloss:0.57648	validation_1-logloss:0.61268
# [552]	validation_0-logloss:0.57636	validation_1-logloss:0.61258
# [553]	validation_0-logloss:0.57627	validation_1-logloss:0.61253
# [554]	validation_0-logloss:0.57614	validation_1-logloss:0.61245
# [555]	validation_0-logloss:0.57602	validation_1-logloss:0.61240
# [556]	validation_0-logloss:0.57588	validation_1-logloss:0.61234
# [557]	validation_0-logloss:0.57574	validation_1-logloss:0.61226
# [558]	validation_0-logloss:0.57565	validation_1-logloss:0.61221
# [559]	validation_0-logloss:0.57554	validation_1-logloss:0.61215
# [560]	validation_0-logloss:0.57548	validation_1-logloss:0.61211
# [561]	validation_0-logloss:0.57539	validation_1-logloss:0.61207
# [562]	validation_0-logloss:0.57528	validation_1-logloss:0.61203
# [563]	validation_0-logloss:0.57514	validation_1-logloss:0.61192
# [564]	validation_0-logloss:0.57499	validation_1-logloss:0.61181
# [565]	validation_0-logloss:0.57491	validation_1-logloss:0.61177
# [566]	validation_0-logloss:0.57476	validation_1-logloss:0.61171
# [567]	validation_0-logloss:0.57462	validation_1-logloss:0.61163
# [568]	validation_0-logloss:0.57452	validation_1-logloss:0.61157
# [569]	validation_0-logloss:0.57440	validation_1-logloss:0.61151
# [570]	validation_0-logloss:0.57428	validation_1-logloss:0.61144
# [571]	validation_0-logloss:0.57417	validation_1-logloss:0.61139
# [572]	validation_0-logloss:0.57404	validation_1-logloss:0.61130
# [573]	validation_0-logloss:0.57393	validation_1-logloss:0.61125
# [574]	validation_0-logloss:0.57380	validation_1-logloss:0.61119
# [575]	validation_0-logloss:0.57367	validation_1-logloss:0.61111
# [576]	validation_0-logloss:0.57354	validation_1-logloss:0.61105
# [577]	validation_0-logloss:0.57342	validation_1-logloss:0.61100
# [578]	validation_0-logloss:0.57330	validation_1-logloss:0.61094
# [579]	validation_0-logloss:0.57315	validation_1-logloss:0.61081
# [580]	validation_0-logloss:0.57308	validation_1-logloss:0.61076
# [581]	validation_0-logloss:0.57298	validation_1-logloss:0.61070
# [582]	validation_0-logloss:0.57283	validation_1-logloss:0.61062
# [583]	validation_0-logloss:0.57275	validation_1-logloss:0.61057
# [584]	validation_0-logloss:0.57265	validation_1-logloss:0.61053
# [585]	validation_0-logloss:0.57254	validation_1-logloss:0.61048
# [586]	validation_0-logloss:0.57246	validation_1-logloss:0.61044
# [587]	validation_0-logloss:0.57228	validation_1-logloss:0.61033
# [588]	validation_0-logloss:0.57220	validation_1-logloss:0.61026
# [589]	validation_0-logloss:0.57208	validation_1-logloss:0.61019
# [590]	validation_0-logloss:0.57202	validation_1-logloss:0.61017
# [591]	validation_0-logloss:0.57194	validation_1-logloss:0.61013
# [592]	validation_0-logloss:0.57180	validation_1-logloss:0.61004
# [593]	validation_0-logloss:0.57171	validation_1-logloss:0.60999
# [594]	validation_0-logloss:0.57159	validation_1-logloss:0.60992
# [595]	validation_0-logloss:0.57148	validation_1-logloss:0.60985
# [596]	validation_0-logloss:0.57136	validation_1-logloss:0.60978
# [597]	validation_0-logloss:0.57122	validation_1-logloss:0.60971
# [598]	validation_0-logloss:0.57111	validation_1-logloss:0.60966
# [599]	validation_0-logloss:0.57100	validation_1-logloss:0.60959
# [600]	validation_0-logloss:0.57088	validation_1-logloss:0.60950
# [601]	validation_0-logloss:0.57076	validation_1-logloss:0.60942
# [602]	validation_0-logloss:0.57070	validation_1-logloss:0.60940
# [603]	validation_0-logloss:0.57055	validation_1-logloss:0.60932
# [604]	validation_0-logloss:0.57044	validation_1-logloss:0.60924
# [605]	validation_0-logloss:0.57032	validation_1-logloss:0.60917
# [606]	validation_0-logloss:0.57015	validation_1-logloss:0.60904
# [607]	validation_0-logloss:0.57000	validation_1-logloss:0.60897
# [608]	validation_0-logloss:0.56985	validation_1-logloss:0.60886
# [609]	validation_0-logloss:0.56972	validation_1-logloss:0.60879
# [610]	validation_0-logloss:0.56959	validation_1-logloss:0.60873
# [611]	validation_0-logloss:0.56947	validation_1-logloss:0.60868
# [612]	validation_0-logloss:0.56936	validation_1-logloss:0.60862
# [613]	validation_0-logloss:0.56927	validation_1-logloss:0.60857
# [614]	validation_0-logloss:0.56915	validation_1-logloss:0.60850
# [615]	validation_0-logloss:0.56900	validation_1-logloss:0.60840
# [616]	validation_0-logloss:0.56888	validation_1-logloss:0.60831
# [617]	validation_0-logloss:0.56880	validation_1-logloss:0.60828
# [618]	validation_0-logloss:0.56867	validation_1-logloss:0.60822
# [619]	validation_0-logloss:0.56857	validation_1-logloss:0.60813
# [620]	validation_0-logloss:0.56847	validation_1-logloss:0.60808
# [621]	validation_0-logloss:0.56835	validation_1-logloss:0.60801
# [622]	validation_0-logloss:0.56825	validation_1-logloss:0.60796
# [623]	validation_0-logloss:0.56814	validation_1-logloss:0.60790
# [624]	validation_0-logloss:0.56803	validation_1-logloss:0.60782
# [625]	validation_0-logloss:0.56792	validation_1-logloss:0.60776
# [626]	validation_0-logloss:0.56784	validation_1-logloss:0.60775
# [627]	validation_0-logloss:0.56774	validation_1-logloss:0.60768
# [628]	validation_0-logloss:0.56765	validation_1-logloss:0.60765
# [629]	validation_0-logloss:0.56758	validation_1-logloss:0.60760
# [630]	validation_0-logloss:0.56746	validation_1-logloss:0.60753
# [631]	validation_0-logloss:0.56735	validation_1-logloss:0.60747
# [632]	validation_0-logloss:0.56727	validation_1-logloss:0.60742
# [633]	validation_0-logloss:0.56719	validation_1-logloss:0.60739
# [634]	validation_0-logloss:0.56706	validation_1-logloss:0.60732
# [635]	validation_0-logloss:0.56695	validation_1-logloss:0.60725
# [636]	validation_0-logloss:0.56680	validation_1-logloss:0.60716
# [637]	validation_0-logloss:0.56671	validation_1-logloss:0.60710
# [638]	validation_0-logloss:0.56659	validation_1-logloss:0.60701
# [639]	validation_0-logloss:0.56653	validation_1-logloss:0.60697
# [640]	validation_0-logloss:0.56645	validation_1-logloss:0.60695
# [641]	validation_0-logloss:0.56637	validation_1-logloss:0.60690
# [642]	validation_0-logloss:0.56629	validation_1-logloss:0.60687
# [643]	validation_0-logloss:0.56618	validation_1-logloss:0.60681
# [644]	validation_0-logloss:0.56607	validation_1-logloss:0.60674
# [645]	validation_0-logloss:0.56596	validation_1-logloss:0.60671
# [646]	validation_0-logloss:0.56584	validation_1-logloss:0.60665
# [647]	validation_0-logloss:0.56573	validation_1-logloss:0.60656
# [648]	validation_0-logloss:0.56563	validation_1-logloss:0.60650
# [649]	validation_0-logloss:0.56553	validation_1-logloss:0.60646
# [650]	validation_0-logloss:0.56537	validation_1-logloss:0.60637
# [651]	validation_0-logloss:0.56528	validation_1-logloss:0.60630
# [652]	validation_0-logloss:0.56516	validation_1-logloss:0.60621
# [653]	validation_0-logloss:0.56503	validation_1-logloss:0.60615
# [654]	validation_0-logloss:0.56492	validation_1-logloss:0.60608
# [655]	validation_0-logloss:0.56478	validation_1-logloss:0.60600
# [656]	validation_0-logloss:0.56468	validation_1-logloss:0.60595
# [657]	validation_0-logloss:0.56459	validation_1-logloss:0.60587
# [658]	validation_0-logloss:0.56448	validation_1-logloss:0.60580
# [659]	validation_0-logloss:0.56434	validation_1-logloss:0.60572
# [660]	validation_0-logloss:0.56421	validation_1-logloss:0.60563
# [661]	validation_0-logloss:0.56411	validation_1-logloss:0.60557
# [662]	validation_0-logloss:0.56398	validation_1-logloss:0.60549
# [663]	validation_0-logloss:0.56389	validation_1-logloss:0.60542
# [664]	validation_0-logloss:0.56382	validation_1-logloss:0.60537
# [665]	validation_0-logloss:0.56371	validation_1-logloss:0.60531
# [666]	validation_0-logloss:0.56360	validation_1-logloss:0.60525
# [667]	validation_0-logloss:0.56353	validation_1-logloss:0.60524
# [668]	validation_0-logloss:0.56346	validation_1-logloss:0.60520
# [669]	validation_0-logloss:0.56337	validation_1-logloss:0.60513
# [670]	validation_0-logloss:0.56324	validation_1-logloss:0.60508
# [671]	validation_0-logloss:0.56317	validation_1-logloss:0.60504
# [672]	validation_0-logloss:0.56305	validation_1-logloss:0.60497
# [673]	validation_0-logloss:0.56295	validation_1-logloss:0.60491
# [674]	validation_0-logloss:0.56287	validation_1-logloss:0.60489
# [675]	validation_0-logloss:0.56280	validation_1-logloss:0.60486
# [676]	validation_0-logloss:0.56268	validation_1-logloss:0.60478
# [677]	validation_0-logloss:0.56255	validation_1-logloss:0.60469
# [678]	validation_0-logloss:0.56242	validation_1-logloss:0.60460
# [679]	validation_0-logloss:0.56230	validation_1-logloss:0.60452
# [680]	validation_0-logloss:0.56224	validation_1-logloss:0.60449
# [681]	validation_0-logloss:0.56215	validation_1-logloss:0.60443
# [682]	validation_0-logloss:0.56207	validation_1-logloss:0.60438
# [683]	validation_0-logloss:0.56196	validation_1-logloss:0.60432
# [684]	validation_0-logloss:0.56186	validation_1-logloss:0.60426
# [685]	validation_0-logloss:0.56175	validation_1-logloss:0.60421
# [686]	validation_0-logloss:0.56164	validation_1-logloss:0.60417
# [687]	validation_0-logloss:0.56152	validation_1-logloss:0.60410
# [688]	validation_0-logloss:0.56143	validation_1-logloss:0.60403
# [689]	validation_0-logloss:0.56127	validation_1-logloss:0.60390
# [690]	validation_0-logloss:0.56114	validation_1-logloss:0.60386
# [691]	validation_0-logloss:0.56105	validation_1-logloss:0.60382
# [692]	validation_0-logloss:0.56095	validation_1-logloss:0.60374
# [693]	validation_0-logloss:0.56088	validation_1-logloss:0.60371
# [694]	validation_0-logloss:0.56079	validation_1-logloss:0.60366
# [695]	validation_0-logloss:0.56067	validation_1-logloss:0.60357
# [696]	validation_0-logloss:0.56058	validation_1-logloss:0.60354
# [697]	validation_0-logloss:0.56042	validation_1-logloss:0.60345
# [698]	validation_0-logloss:0.56033	validation_1-logloss:0.60341
# [699]	validation_0-logloss:0.56024	validation_1-logloss:0.60337
# [700]	validation_0-logloss:0.56014	validation_1-logloss:0.60331
# [701]	validation_0-logloss:0.56010	validation_1-logloss:0.60330
# [702]	validation_0-logloss:0.56000	validation_1-logloss:0.60325
# [703]	validation_0-logloss:0.55990	validation_1-logloss:0.60319
# [704]	validation_0-logloss:0.55981	validation_1-logloss:0.60315
# [705]	validation_0-logloss:0.55974	validation_1-logloss:0.60310
# [706]	validation_0-logloss:0.55965	validation_1-logloss:0.60307
# [707]	validation_0-logloss:0.55952	validation_1-logloss:0.60295
# [708]	validation_0-logloss:0.55940	validation_1-logloss:0.60290
# [709]	validation_0-logloss:0.55929	validation_1-logloss:0.60285
# [710]	validation_0-logloss:0.55921	validation_1-logloss:0.60283
# [711]	validation_0-logloss:0.55912	validation_1-logloss:0.60280
# [712]	validation_0-logloss:0.55902	validation_1-logloss:0.60275
# [713]	validation_0-logloss:0.55891	validation_1-logloss:0.60272
# [714]	validation_0-logloss:0.55881	validation_1-logloss:0.60269
# [715]	validation_0-logloss:0.55870	validation_1-logloss:0.60262
# [716]	validation_0-logloss:0.55860	validation_1-logloss:0.60257
# [717]	validation_0-logloss:0.55851	validation_1-logloss:0.60255
# [718]	validation_0-logloss:0.55844	validation_1-logloss:0.60249
# [719]	validation_0-logloss:0.55833	validation_1-logloss:0.60242
# [720]	validation_0-logloss:0.55822	validation_1-logloss:0.60234
# [721]	validation_0-logloss:0.55812	validation_1-logloss:0.60228
# [722]	validation_0-logloss:0.55803	validation_1-logloss:0.60223
# [723]	validation_0-logloss:0.55798	validation_1-logloss:0.60221
# [724]	validation_0-logloss:0.55787	validation_1-logloss:0.60214
# [725]	validation_0-logloss:0.55780	validation_1-logloss:0.60210
# [726]	validation_0-logloss:0.55770	validation_1-logloss:0.60206
# [727]	validation_0-logloss:0.55761	validation_1-logloss:0.60200
# [728]	validation_0-logloss:0.55751	validation_1-logloss:0.60196
# [729]	validation_0-logloss:0.55739	validation_1-logloss:0.60189
# [730]	validation_0-logloss:0.55731	validation_1-logloss:0.60182
# [731]	validation_0-logloss:0.55724	validation_1-logloss:0.60179
# [732]	validation_0-logloss:0.55718	validation_1-logloss:0.60175
# [733]	validation_0-logloss:0.55708	validation_1-logloss:0.60169
# [734]	validation_0-logloss:0.55701	validation_1-logloss:0.60168
# [735]	validation_0-logloss:0.55691	validation_1-logloss:0.60161
# [736]	validation_0-logloss:0.55680	validation_1-logloss:0.60155
# [737]	validation_0-logloss:0.55668	validation_1-logloss:0.60149
# [738]	validation_0-logloss:0.55659	validation_1-logloss:0.60144
# [739]	validation_0-logloss:0.55647	validation_1-logloss:0.60136
# [740]	validation_0-logloss:0.55638	validation_1-logloss:0.60130
# [741]	validation_0-logloss:0.55626	validation_1-logloss:0.60121
# [742]	validation_0-logloss:0.55618	validation_1-logloss:0.60118
# [743]	validation_0-logloss:0.55606	validation_1-logloss:0.60112
# [744]	validation_0-logloss:0.55598	validation_1-logloss:0.60108
# [745]	validation_0-logloss:0.55587	validation_1-logloss:0.60101
# [746]	validation_0-logloss:0.55580	validation_1-logloss:0.60098
# ...
# [2177]	validation_0-logloss:0.46844	validation_1-logloss:0.57139
# [2178]	validation_0-logloss:0.46839	validation_1-logloss:0.57138
# [2179]	validation_0-logloss:0.46836	validation_1-logloss:0.57139
# [2180]	validation_0-logloss:0.46833	validation_1-logloss:0.57138
# [2181]	validation_0-logloss:0.46829	validation_1-logloss:0.57138
# [2182]	validation_0-logloss:0.46827	validation_1-logloss:0.57139
# [2183]	validation_0-logloss:0.46822	validation_1-logloss:0.57138
# [2184]	validation_0-logloss:0.46819	validation_1-logloss:0.57137
# [2185]	validation_0-logloss:0.46815	validation_1-logloss:0.57136
# [2186]	validation_0-logloss:0.46812	validation_1-logloss:0.57137
# [2187]	validation_0-logloss:0.46808	validation_1-logloss:0.57136
# [2188]	validation_0-logloss:0.46804	validation_1-logloss:0.57135
# [2189]	validation_0-logloss:0.46799	validation_1-logloss:0.57133
# [2190]	validation_0-logloss:0.46794	validation_1-logloss:0.57133
# [2191]	validation_0-logloss:0.46790	validation_1-logloss:0.57135
# [2192]	validation_0-logloss:0.46787	validation_1-logloss:0.57134
# [2193]	validation_0-logloss:0.46783	validation_1-logloss:0.57133
# [2194]	validation_0-logloss:0.46777	validation_1-logloss:0.57133
# [2195]	validation_0-logloss:0.46772	validation_1-logloss:0.57133
# [2196]	validation_0-logloss:0.46769	validation_1-logloss:0.57131
# [2197]	validation_0-logloss:0.46764	validation_1-logloss:0.57131
# [2198]	validation_0-logloss:0.46760	validation_1-logloss:0.57131
# [2199]	validation_0-logloss:0.46756	validation_1-logloss:0.57130
# [2200]	validation_0-logloss:0.46752	validation_1-logloss:0.57129
# [2201]	validation_0-logloss:0.46748	validation_1-logloss:0.57130
# [2202]	validation_0-logloss:0.46743	validation_1-logloss:0.57129
# [2203]	validation_0-logloss:0.46739	validation_1-logloss:0.57129
# [2204]	validation_0-logloss:0.46734	validation_1-logloss:0.57129
# [2205]	validation_0-logloss:0.46729	validation_1-logloss:0.57128
# [2206]	validation_0-logloss:0.46725	validation_1-logloss:0.57128
# [2207]	validation_0-logloss:0.46720	validation_1-logloss:0.57127
# [2208]	validation_0-logloss:0.46716	validation_1-logloss:0.57127
# [2209]	validation_0-logloss:0.46711	validation_1-logloss:0.57127
# [2210]	validation_0-logloss:0.46706	validation_1-logloss:0.57127
# [2211]	validation_0-logloss:0.46703	validation_1-logloss:0.57127
# [2212]	validation_0-logloss:0.46698	validation_1-logloss:0.57127
# [2213]	validation_0-logloss:0.46693	validation_1-logloss:0.57127
# [2214]	validation_0-logloss:0.46689	validation_1-logloss:0.57127
# [2215]	validation_0-logloss:0.46684	validation_1-logloss:0.57127
# [2216]	validation_0-logloss:0.46680	validation_1-logloss:0.57127
# [2217]	validation_0-logloss:0.46675	validation_1-logloss:0.57127
# [2218]	validation_0-logloss:0.46670	validation_1-logloss:0.57125
# [2219]	validation_0-logloss:0.46666	validation_1-logloss:0.57124
# [2220]	validation_0-logloss:0.46662	validation_1-logloss:0.57125
# [2221]	validation_0-logloss:0.46658	validation_1-logloss:0.57122
# [2222]	validation_0-logloss:0.46653	validation_1-logloss:0.57122
# [2223]	validation_0-logloss:0.46649	validation_1-logloss:0.57122
# [2224]	validation_0-logloss:0.46644	validation_1-logloss:0.57122
# [2225]	validation_0-logloss:0.46640	validation_1-logloss:0.57123
# [2226]	validation_0-logloss:0.46637	validation_1-logloss:0.57123
# [2227]	validation_0-logloss:0.46632	validation_1-logloss:0.57121
# [2228]	validation_0-logloss:0.46628	validation_1-logloss:0.57123
# [2229]	validation_0-logloss:0.46625	validation_1-logloss:0.57123
# [2230]	validation_0-logloss:0.46621	validation_1-logloss:0.57123
# [2231]	validation_0-logloss:0.46617	validation_1-logloss:0.57124
# [2232]	validation_0-logloss:0.46613	validation_1-logloss:0.57124
# [2233]	validation_0-logloss:0.46609	validation_1-logloss:0.57123
# [2234]	validation_0-logloss:0.46604	validation_1-logloss:0.57122
# [2235]	validation_0-logloss:0.46600	validation_1-logloss:0.57121
# [2236]	validation_0-logloss:0.46595	validation_1-logloss:0.57119
# [2237]	validation_0-logloss:0.46592	validation_1-logloss:0.57119
# [2238]	validation_0-logloss:0.46587	validation_1-logloss:0.57118
# [2239]	validation_0-logloss:0.46583	validation_1-logloss:0.57117
# [2240]	validation_0-logloss:0.46578	validation_1-logloss:0.57116
# [2241]	validation_0-logloss:0.46574	validation_1-logloss:0.57115
# [2242]	validation_0-logloss:0.46569	validation_1-logloss:0.57114
# [2243]	validation_0-logloss:0.46564	validation_1-logloss:0.57113
# [2244]	validation_0-logloss:0.46561	validation_1-logloss:0.57114
# [2245]	validation_0-logloss:0.46557	validation_1-logloss:0.57113
# [2246]	validation_0-logloss:0.46553	validation_1-logloss:0.57111
# [2247]	validation_0-logloss:0.46549	validation_1-logloss:0.57111
# [2248]	validation_0-logloss:0.46546	validation_1-logloss:0.57110
# [2249]	validation_0-logloss:0.46542	validation_1-logloss:0.57110
# [2250]	validation_0-logloss:0.46537	validation_1-logloss:0.57110
# [2251]	validation_0-logloss:0.46534	validation_1-logloss:0.57111
# [2252]	validation_0-logloss:0.46531	validation_1-logloss:0.57111
# [2253]	validation_0-logloss:0.46526	validation_1-logloss:0.57112
# [2254]	validation_0-logloss:0.46521	validation_1-logloss:0.57110
# [2255]	validation_0-logloss:0.46516	validation_1-logloss:0.57108
# [2256]	validation_0-logloss:0.46513	validation_1-logloss:0.57107
# [2257]	validation_0-logloss:0.46510	validation_1-logloss:0.57106
# [2258]	validation_0-logloss:0.46505	validation_1-logloss:0.57104
# [2259]	validation_0-logloss:0.46500	validation_1-logloss:0.57103
# [2260]	validation_0-logloss:0.46495	validation_1-logloss:0.57102
# [2261]	validation_0-logloss:0.46491	validation_1-logloss:0.57102
# [2262]	validation_0-logloss:0.46488	validation_1-logloss:0.57102
# [2263]	validation_0-logloss:0.46483	validation_1-logloss:0.57101
# [2264]	validation_0-logloss:0.46478	validation_1-logloss:0.57098
# [2265]	validation_0-logloss:0.46474	validation_1-logloss:0.57099
# [2266]	validation_0-logloss:0.46469	validation_1-logloss:0.57098
# [2267]	validation_0-logloss:0.46465	validation_1-logloss:0.57098
# [2268]	validation_0-logloss:0.46460	validation_1-logloss:0.57097
# [2269]	validation_0-logloss:0.46457	validation_1-logloss:0.57096
# [2270]	validation_0-logloss:0.46453	validation_1-logloss:0.57097
# [2271]	validation_0-logloss:0.46450	validation_1-logloss:0.57097
# [2272]	validation_0-logloss:0.46445	validation_1-logloss:0.57097
# [2273]	validation_0-logloss:0.46441	validation_1-logloss:0.57096
# [2274]	validation_0-logloss:0.46438	validation_1-logloss:0.57095
# [2275]	validation_0-logloss:0.46434	validation_1-logloss:0.57095
# [2276]	validation_0-logloss:0.46430	validation_1-logloss:0.57094
# [2277]	validation_0-logloss:0.46425	validation_1-logloss:0.57093
# [2278]	validation_0-logloss:0.46421	validation_1-logloss:0.57092
# [2279]	validation_0-logloss:0.46417	validation_1-logloss:0.57090
# [2280]	validation_0-logloss:0.46414	validation_1-logloss:0.57089
# [2281]	validation_0-logloss:0.46410	validation_1-logloss:0.57089
# [2282]	validation_0-logloss:0.46406	validation_1-logloss:0.57088
# [2283]	validation_0-logloss:0.46402	validation_1-logloss:0.57087
# [2284]	validation_0-logloss:0.46398	validation_1-logloss:0.57089
# [2285]	validation_0-logloss:0.46394	validation_1-logloss:0.57089
# [2286]	validation_0-logloss:0.46389	validation_1-logloss:0.57089
# [2287]	validation_0-logloss:0.46384	validation_1-logloss:0.57089
# [2288]	validation_0-logloss:0.46379	validation_1-logloss:0.57089
# [2289]	validation_0-logloss:0.46376	validation_1-logloss:0.57091
# [2290]	validation_0-logloss:0.46371	validation_1-logloss:0.57089
# [2291]	validation_0-logloss:0.46366	validation_1-logloss:0.57089
# [2292]	validation_0-logloss:0.46362	validation_1-logloss:0.57090
# [2293]	validation_0-logloss:0.46358	validation_1-logloss:0.57090
# [2294]	validation_0-logloss:0.46354	validation_1-logloss:0.57090
# [2295]	validation_0-logloss:0.46350	validation_1-logloss:0.57089
# [2296]	validation_0-logloss:0.46347	validation_1-logloss:0.57089
# [2297]	validation_0-logloss:0.46342	validation_1-logloss:0.57089
# [2298]	validation_0-logloss:0.46337	validation_1-logloss:0.57084
# [2299]	validation_0-logloss:0.46332	validation_1-logloss:0.57085
# [2300]	validation_0-logloss:0.46328	validation_1-logloss:0.57085
# [2301]	validation_0-logloss:0.46324	validation_1-logloss:0.57087
# [2302]	validation_0-logloss:0.46321	validation_1-logloss:0.57088
# [2303]	validation_0-logloss:0.46317	validation_1-logloss:0.57087
# [2304]	validation_0-logloss:0.46313	validation_1-logloss:0.57087
# [2305]	validation_0-logloss:0.46309	validation_1-logloss:0.57084
# [2306]	validation_0-logloss:0.46306	validation_1-logloss:0.57084
# [2307]	validation_0-logloss:0.46301	validation_1-logloss:0.57083
# [2308]	validation_0-logloss:0.46296	validation_1-logloss:0.57083
# [2309]	validation_0-logloss:0.46292	validation_1-logloss:0.57083
# [2310]	validation_0-logloss:0.46289	validation_1-logloss:0.57083
# [2311]	validation_0-logloss:0.46285	validation_1-logloss:0.57083
# [2312]	validation_0-logloss:0.46280	validation_1-logloss:0.57083
# [2313]	validation_0-logloss:0.46275	validation_1-logloss:0.57083
# [2314]	validation_0-logloss:0.46272	validation_1-logloss:0.57082
# [2315]	validation_0-logloss:0.46268	validation_1-logloss:0.57083
# [2316]	validation_0-logloss:0.46263	validation_1-logloss:0.57082
# [2317]	validation_0-logloss:0.46259	validation_1-logloss:0.57081
# [2318]	validation_0-logloss:0.46255	validation_1-logloss:0.57079
# [2319]	validation_0-logloss:0.46252	validation_1-logloss:0.57078
# [2320]	validation_0-logloss:0.46248	validation_1-logloss:0.57078
# [2321]	validation_0-logloss:0.46242	validation_1-logloss:0.57077
# [2322]	validation_0-logloss:0.46238	validation_1-logloss:0.57077
# [2323]	validation_0-logloss:0.46234	validation_1-logloss:0.57078
# [2324]	validation_0-logloss:0.46229	validation_1-logloss:0.57078
# [2325]	validation_0-logloss:0.46226	validation_1-logloss:0.57077
# [2326]	validation_0-logloss:0.46223	validation_1-logloss:0.57077
# [2327]	validation_0-logloss:0.46218	validation_1-logloss:0.57076
# [2328]	validation_0-logloss:0.46215	validation_1-logloss:0.57075
# [2329]	validation_0-logloss:0.46210	validation_1-logloss:0.57076
# [2330]	validation_0-logloss:0.46205	validation_1-logloss:0.57076
# [2331]	validation_0-logloss:0.46200	validation_1-logloss:0.57073
# [2332]	validation_0-logloss:0.46198	validation_1-logloss:0.57073
# [2333]	validation_0-logloss:0.46193	validation_1-logloss:0.57074
# [2334]	validation_0-logloss:0.46189	validation_1-logloss:0.57074
# [2335]	validation_0-logloss:0.46185	validation_1-logloss:0.57074
# [2336]	validation_0-logloss:0.46181	validation_1-logloss:0.57075
# [2337]	validation_0-logloss:0.46177	validation_1-logloss:0.57076
# [2338]	validation_0-logloss:0.46173	validation_1-logloss:0.57075
# [2339]	validation_0-logloss:0.46168	validation_1-logloss:0.57074
# [2340]	validation_0-logloss:0.46165	validation_1-logloss:0.57072
# [2341]	validation_0-logloss:0.46161	validation_1-logloss:0.57073
# [2342]	validation_0-logloss:0.46157	validation_1-logloss:0.57072
# [2343]	validation_0-logloss:0.46154	validation_1-logloss:0.57072
# [2344]	validation_0-logloss:0.46149	validation_1-logloss:0.57071
# [2345]	validation_0-logloss:0.46145	validation_1-logloss:0.57070
# [2346]	validation_0-logloss:0.46141	validation_1-logloss:0.57070
# [2347]	validation_0-logloss:0.46137	validation_1-logloss:0.57069
# [2348]	validation_0-logloss:0.46131	validation_1-logloss:0.57069
# [2349]	validation_0-logloss:0.46127	validation_1-logloss:0.57068
# [2350]	validation_0-logloss:0.46122	validation_1-logloss:0.57068
# [2351]	validation_0-logloss:0.46118	validation_1-logloss:0.57068
# [2352]	validation_0-logloss:0.46114	validation_1-logloss:0.57068
# [2353]	validation_0-logloss:0.46109	validation_1-logloss:0.57067
# [2354]	validation_0-logloss:0.46106	validation_1-logloss:0.57067
# [2355]	validation_0-logloss:0.46102	validation_1-logloss:0.57068
# [2356]	validation_0-logloss:0.46099	validation_1-logloss:0.57068
# [2357]	validation_0-logloss:0.46095	validation_1-logloss:0.57067
# [2358]	validation_0-logloss:0.46090	validation_1-logloss:0.57066
# [2359]	validation_0-logloss:0.46085	validation_1-logloss:0.57063
# [2360]	validation_0-logloss:0.46082	validation_1-logloss:0.57062
# [2361]	validation_0-logloss:0.46077	validation_1-logloss:0.57062
# [2362]	validation_0-logloss:0.46073	validation_1-logloss:0.57060
# [2363]	validation_0-logloss:0.46069	validation_1-logloss:0.57060
# [2364]	validation_0-logloss:0.46064	validation_1-logloss:0.57060
# [2365]	validation_0-logloss:0.46060	validation_1-logloss:0.57061
# [2366]	validation_0-logloss:0.46056	validation_1-logloss:0.57062
# [2367]	validation_0-logloss:0.46051	validation_1-logloss:0.57060
# [2368]	validation_0-logloss:0.46047	validation_1-logloss:0.57061
# [2369]	validation_0-logloss:0.46044	validation_1-logloss:0.57061
# [2370]	validation_0-logloss:0.46039	validation_1-logloss:0.57060
# [2371]	validation_0-logloss:0.46036	validation_1-logloss:0.57060
# [2372]	validation_0-logloss:0.46031	validation_1-logloss:0.57060
# [2373]	validation_0-logloss:0.46028	validation_1-logloss:0.57059
# [2374]	validation_0-logloss:0.46024	validation_1-logloss:0.57058
# [2375]	validation_0-logloss:0.46020	validation_1-logloss:0.57058
# [2376]	validation_0-logloss:0.46015	validation_1-logloss:0.57058
# [2377]	validation_0-logloss:0.46010	validation_1-logloss:0.57056
# [2378]	validation_0-logloss:0.46006	validation_1-logloss:0.57055
# [2379]	validation_0-logloss:0.46003	validation_1-logloss:0.57055
# [2380]	validation_0-logloss:0.45998	validation_1-logloss:0.57053
# [2381]	validation_0-logloss:0.45993	validation_1-logloss:0.57051
# [2382]	validation_0-logloss:0.45988	validation_1-logloss:0.57051
# [2383]	validation_0-logloss:0.45984	validation_1-logloss:0.57050
# [2384]	validation_0-logloss:0.45980	validation_1-logloss:0.57049
# [2385]	validation_0-logloss:0.45975	validation_1-logloss:0.57049
# [2386]	validation_0-logloss:0.45971	validation_1-logloss:0.57049
# [2387]	validation_0-logloss:0.45967	validation_1-logloss:0.57049
# [2388]	validation_0-logloss:0.45962	validation_1-logloss:0.57048
# [2389]	validation_0-logloss:0.45957	validation_1-logloss:0.57048
# [2390]	validation_0-logloss:0.45953	validation_1-logloss:0.57047
# [2391]	validation_0-logloss:0.45949	validation_1-logloss:0.57045
# [2392]	validation_0-logloss:0.45946	validation_1-logloss:0.57045
# [2393]	validation_0-logloss:0.45942	validation_1-logloss:0.57046
# [2394]	validation_0-logloss:0.45938	validation_1-logloss:0.57046
# [2395]	validation_0-logloss:0.45933	validation_1-logloss:0.57047
# [2396]	validation_0-logloss:0.45929	validation_1-logloss:0.57047
# [2397]	validation_0-logloss:0.45925	validation_1-logloss:0.57047
# [2398]	validation_0-logloss:0.45921	validation_1-logloss:0.57048
# [2399]	validation_0-logloss:0.45918	validation_1-logloss:0.57048
# [2400]	validation_0-logloss:0.45914	validation_1-logloss:0.57047
# [2401]	validation_0-logloss:0.45910	validation_1-logloss:0.57047
# [2402]	validation_0-logloss:0.45905	validation_1-logloss:0.57047
# [2403]	validation_0-logloss:0.45901	validation_1-logloss:0.57047
# [2404]	validation_0-logloss:0.45898	validation_1-logloss:0.57048
# [2405]	validation_0-logloss:0.45894	validation_1-logloss:0.57050
# [2406]	validation_0-logloss:0.45891	validation_1-logloss:0.57050
# [2407]	validation_0-logloss:0.45887	validation_1-logloss:0.57050
# [2408]	validation_0-logloss:0.45883	validation_1-logloss:0.57051
# [2409]	validation_0-logloss:0.45879	validation_1-logloss:0.57051
# [2410]	validation_0-logloss:0.45874	validation_1-logloss:0.57051
# [2411]	validation_0-logloss:0.45869	validation_1-logloss:0.57052
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0.5, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.01, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=4, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=10000,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=5, reg_lambda=10, ...)

# %% [markdown]
# ## Score accuracy:

# %%
from sklearn.metrics import accuracy_score

# Predict
preds = xgb_cl.predict(X_test)

# Score
accuracy_score(y_test, preds)
# Out:
# 0.7049180327868853

# %%
# Save model:
xgb_cl.save_model("./submission/model_xgboost.txt")
